# %%
spark.conf.set("fs.azure.account.key.mystore1984.dfs.core.windows.net", "XXXXX")
df = spark.read.format("delta").load("abfss://presentation@mystore1984.dfs.core.windows.net/finaldata_delta/")
df.count()
# Out:
# Out[1]: 398

# %%
df.show(2)
# Out:
# +------------+--------+---------+---------+---------+----------+---------+-----------+------------+---------+------+----+--------------------+
# |SalesOrderID|OrderQty|ProductID|UnitPrice|LineTotal| Salesdate|     Date|ProductName|StandardCost|ListPrice|Weight|Size|        CategoryName|
# +------------+--------+---------+---------+---------+----------+---------+-----------+------------+---------+------+----+--------------------+
# |       71784|      10|      707|   20.994|   209.94|2008-06-01|2025-3-21|    Helmets|     13.0863|    34.99|  null|null|Sport-100 Helmet,...|
# |       71783|      10|      707|   20.994|   209.94|2008-06-01|2025-3-21|    Helmets|     13.0863|    34.99|  null|null|Sport-100 Helmet,...|
# +------------+--------+---------+---------+---------+----------+---------+-----------+------------+---------+------+----+--------------------+
# only showing top 2 rows

# %%
from delta.tables import DeltaTable
delta_table = DeltaTable.forPath(spark, "abfss://presentation@mystore1984.dfs.core.windows.net/finaldata_delta/")
delta_table.history().show()
# Out:
# +-------+-------------------+----------------+--------------------+---------+--------------------+--------------------+------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# |version|          timestamp|          userId|            userName|operation| operationParameters|                 job|          notebook|           clusterId|readVersion|   isolationLevel|isBlindAppend|    operationMetrics|userMetadata|          engineInfo|
# +-------+-------------------+----------------+--------------------+---------+--------------------+--------------------+------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+
# |      1|2025-12-11 18:42:55|3312764505483416|kuldip.mitra@onta...|    WRITE|{mode -> Append, ...|{92634860260032, ...|{1470960754255526}|1211-175027-lb4pm17e|          0|WriteSerializable|         true|{numFiles -> 1, n...|        null|Databricks-Runtim...|
# |      0|2025-12-11 18:30:49|3312764505483416|kuldip.mitra@onta...|    WRITE|{mode -> Overwrit...|{633037204729674,...|{1470960754255526}|1211-175027-lb4pm17e|       null|WriteSerializable|        false|{numFiles -> 1, n...|        null|Databricks-Runtim...|
# +-------+-------------------+----------------+--------------------+---------+--------------------+--------------------+------------------+--------------------+-----------+-----------------+-------------+--------------------+------------+--------------------+

# %%
# load previous version
df_prev = spark.read.format("delta").option("versionAsOf", 0).load("abfss://presentation@mystore1984.dfs.core.windows.net/finaldata_delta/")
df_prev.count()
# Out:
# Out[4]: 199

# %%
# %sql
create database calculation
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
use calculation
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
df_prev.write.format("delta").mode("overwrite").saveAsTable("table_delta")

# %%
# %sql
select * from table_delta
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SalesOrderID</th><th>OrderQty</th><th>ProductID</th><th>UnitPrice</th><th>LineTotal</th><th>Salesdate</th><th>Date</th><th>ProductName</th><th>StandardCost</th><th>ListPrice</th><th>Weight</th><th>Size</th><th>CategoryName</th></tr></thead><tbody><tr><td>71784</td><td>10</td><td>707</td><td>20.994</td><td>209.94</td><td>2008-06-01</td><td>2025-3-21</td><td>Helmets</td><td>13.0863</td><td>34.99</td><td>null</td><td>null</td><td>Sport-100 Helmet, Red</td></tr><tr><td>71783</td><td>10</td><td>707</td><td>20.994</td><td>209.94</td><td>2008-06-01</td><td>2025-3-21</td><td>Helmets</td><td>13.0863</td><td>34.99</td><td>null</td><td>null</td><td>Sport-100 Helmet, Red</td></tr><tr><td>71782</td><td>3</td><td>707</td><td>20.994</td><td>62.982</td><td