# %%
storage_account_name= 'AAAAAAAAA'
client_id='XXXXXXXXXXXXX'
tenant_id= 'XXXXXXXXXXXXXXX'
client_secret= 'XXXXXXXXXXXXXX'
raw_folder_path="abfss://rawdata@AAAAAAAA.dfs.core.windows.net"
processed_folder_path= "abfss://processeddata@AAAAAAAAA.dfs.core.windows.net"
presentation_folder_path= "abfss://finaldata@AAAAAAAAAA.dfs.core.windows.net"
