# %%
raw_folder_path="abfss://rawdata@container.dfs.core.windows.net"
processed_folder_path= "abfss://processeddata@container.dfs.core.windows.net"
presentation_folder_path= "abfss://presentation@container.dfs.core.windows.net"
key="XXXXXX"
