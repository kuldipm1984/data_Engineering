# %%
dbutils.notebook.run('customer',0,{'Date':'2025-3-21'} )

# %%
df=dbutils.notebook.run('product',0, {'Date':'2025-3-21'} )

# %%
df=dbutils.notebook.run('sales',0,{'Date':'2025-3-21'} )

# %%
df=dbutils.notebook.run('calculation',0 )
