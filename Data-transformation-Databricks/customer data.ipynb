# %%
# %run "./config"

# %%
dbutils.widgets.text('Date','')
input_value= dbutils.widgets.get('Date')

# %%
import pyspark
# Create a spark session using getOrCreate() function 
from pyspark.sql import SparkSession 
spark_session = SparkSession.builder.getOrCreate()

# %%
df = spark_session.read.format( 
    "csv").option( 
    "header", True).load('/FileStore/initial data/customer_data.csv')

# %%
df.show()
# Out:
# +----------+-----+-----------+----------+----------+--------------------+--------------------+--------------------+-------------------+--------------------+------------+--------------------+--------------------+
# |CustomerID|Title|  FirstName|MiddleName|  LastName|         CompanyName|         SalesPerson|        EmailAddress|              Phone|        PasswordHash|PasswordSalt|             rowguid|        ModifiedDate|
# +----------+-----+-----------+----------+----------+--------------------+--------------------+--------------------+-------------------+--------------------+------------+--------------------+--------------------+
# |         1|  Mr.|    Orlando|        N.|       Gee|        A Bike Store|adventure-works\p...|orlando0@adventur...|       245-555-0173|L/Rlwxzp4w7RWmEgX...|    1KjXYs4=|3f5ae95e-b87d-4ae...|2005-08-01T00:00:...|
# |         2|  Mr.|      Keith|      null|    Harris|  Progressive Sports|adventure-works\d...|keith0@adventure-...|       170-555-0127|YPdtRdvqeAhj6wyxE...|    fs1ZGhY=|e552f657-a9af-4a7...|2006-08-01T00:00:...|
# |         3|  Ms.|      Donna|        F.|  Carreras|Advanced Bike Com...|adventure-works\j...|donna0@adventure-...|       279-555-0130|LNoK27abGQo48gGue...|    YTNH5Rw=|130774b1-db21-4ef...|2005-09-01T00:00:...|
# |         4|  Ms.|      Janet|        M.|     Gates|Modular Cycle Sys...|adventure-works\j...|janet1@adventure-...|       710-555-0173|ElzTpSNbUW1Ut+L5c...|    nm7D5e4=|ff862851-1daa-404...|2006-07-01T00:00:...|
# |         5|  Mr.|       Lucy|      null|Harrington|Metropolitan Spor...|adventure-works\shu0|lucy0@adventure-w...|       828-555-0186|KJqV15wsX3PG8TS5G...|    cNFKU4w=|83905bdc-6f5e-4f7...|2006-09-01T00:00:...|
# |         6|  Ms.|   Rosmarie|        J.|   Carroll|Aerobic Exercise ...|adventure-works\l...|rosmarie0@adventu...|       244-555-0112|OKT0scizCdIzymHHO...|    ihWf50M=|1a92df88-bfa2-467...|2007-09-01T00:00:...|
# |         7|  Mr.|    Dominic|        P.|      Gash|    Associated Bikes|adventure-works\shu0|dominic0@adventur...|       192-555-0173|ZccoP/jZGQm+Xpzc7...|    sPoUBSQ=|03e9273e-b193-448...|2006-07-01T00:00:...|
# |        10|  Ms.|   Kathleen|        M.|     Garza|Rural Cycle Emporium|adventure-works\j...|kathleen0@adventu...|       150-555-0127|Qa3aMCxNbVLGrc0b9...|    Ls05W3g=|cdb6698d-2ff1-4fb...|2006-09-01T00:00:...|
# |        11|  Ms.|  Katherine|      null|   Harding|         Sharp Bikes|adventure-works\j...|katherine0@advent...|       926-555-0159|uRlorVzDGNJIX9I+e...|    jpHKbqE=|750f3495-59c4-48a...|2005-08-01T00:00:...|
# |        12|  Mr.|     Johnny|        A.|    Caprio|Bikes and Motorbikes|adventure-works\g...|johnny0@adventure...|       112-555-0191|jtF9jBoFYeJTaET7x...|    wVLnvHo=|947bcaf1-1f32-44f...|2006-08-01T00:00:...|
# |        16|  Mr.|Christopher|        R.|      Beck| Bulk Discount Store|adventure-works\jae0|christopher1@adve...|1 (11) 500 555-0132|sKt9daCzEEKWAzivE...|    8KfYx/4=|c9381589-d31c-4ef...|2006-09-01T00:00:...|
# |        18|  Mr.|      David|        J.|       Liu|       Catalog Store|adventure-works\m...|david20@adventure...|       440-555-0132|61zeTkO+eI5g8GG0s...|    c7Ttvv0=|c04d6b4d-94c6-4c5...|2005-08-01T00:00:...|
# |        19|  Mr.|       John|        A.|    Beaver|   Center Cycle Shop|adventure-works\p...|john8@adventure-w...|       521-555-0195|DzbqWX7B3EK5Dub92...|    zXNgrJw=|69ae5d43-31be-4b7...|2007-04-01T00:00:...|
# |        20|  Ms.|       Jean|        P.|   Handley|Central Discount ...|adventure-works\d...|jean1@adventure-w...|       582-555-0113|o1GVo3vExeNzo0/ct...|    uMsvfdo=|e010c10a-f1c3-4bb...|2005-09-01T00:00:...|
# |        21| null|    Jinghao|      null|       Liu|Chic Department S...|adventure-works\j...|jinghao1@adventur...|       928-555-0116|IaD5AeqK9mRiIrJi/...|    p6pOqKc=|564e0b42-4609-43d...|2006-09-01T00:00:...|
# |        22|  Ms.|      Linda|        E.|   Burnett|      Travel Systems|adventure-works\j...|linda4@adventure-...|       121-555-0121|23AwhujCoXYSPiN/B...|    SmyIPjE=|9774aed6-d673-412...|2005-08-01T00:00:...|
# |        23|  Mr.|      Kerim|      null|     Hanif|          Bike World|adventure-works\shu0|kerim0@adventure-...|       216-555-0122|d0WSjosAd7Y3XOWjN...|    33g5co8=|733f8250-3251-4c2...|2006-09-01T00:00:...|
# |        24|  Mr.|      Kevin|      null|       Liu|Eastside Departme...|adventure-works\l...|kevin5@adventure-...|       926-555-0164|ylTpkIOHKLcjihNjS...|    TgZnUOg=|c111e51d-178d-4db...|2006-09-01T00:00:...|
# |        25|  Mr.|     Donald|        L.|   Blanton|Coalition Bike Co...|adventure-works\shu0|donald0@adventure...|       357-555-0161|pKYDelLBOZMO98GBz...|    jKtOaOw=|31d03546-fb2a-448...|2006-09-01T00:00:...|
# |        28|  Ms.|     Jackie|        E.| Blackwell|Commuter Bicycle ...|adventure-works\j...|jackie0@adventure...|       972-555-0163|wqhgKfOTfef4Zo3cb...|    SZ+r60o=|9b8a04a4-d909-4f4...|2007-08-01T00:00:...|
# +----------+-----+-----------+----------+----------+--------------------+--------------------+--------------------+-------------------+--------------------+------------+--------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col,concat_ws, current_timestamp, lit, split
df_modified= df.withColumn('CustomerName', concat_ws('',col ("Title"), lit(' '), col("FirstName"),lit(' '), col("MiddleName"),lit(' '), col 
                ("LastName")))\
               .drop('PasswordHash','PasswordSalt','rowguid','ModifiedDate','Title','FirstName','LastName','MiddleName')\
               .withColumn("Date",lit(input_value))

# %%
df_modified.printSchema()
# Out:
# root
#  |-- CustomerID: string (nullable = true)
#  |-- CompanyName: string (nullable = true)
#  |-- SalesPerson: string (nullable = true)
#  |-- EmailAddress: string (nullable = true)
#  |-- Phone: string (nullable = true)
#  |-- CustomerName: string (nullable = false)
#  |-- Date: string (nullable = false)

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import IntegerType, StringType, DateType

df_modified = (df_modified
               .withColumn("CustomerID", col("CustomerID").cast(IntegerType()))
               .withColumn("CompanyName", col("CompanyName").cast(StringType()))
               .withColumn("SalesPerson", col("SalesPerson").cast(StringType()))
               .withColumn("EmailAddress", col("EmailAddress").cast(StringType()))
               .withColumn("Phone", col("Phone").cast(StringType()))
               .withColumn("CustomerName", col("CustomerName").cast(StringType()))
               .withColumn("Date", col("Date").cast(DateType())))  # Cast Date to DateType

# %%
df_modified.printSchema()
# Out:
# root
#  |-- CustomerID: integer (nullable = true)
#  |-- CompanyName: string (nullable = true)
#  |-- SalesPerson: string (nullable = true)
#  |-- EmailAddress: string (nullable = true)
#  |-- Phone: string (nullable = true)
#  |-- CustomerName: string (nullable = false)
#  |-- Date: date (nullable = true)

# %%
df_modified.show()
# Out:
# +----------+--------------------+--------------------+--------------------+-------------------+--------------------+----+
# |CustomerID|         CompanyName|         SalesPerson|        EmailAddress|              Phone|        CustomerName|Date|
# +----------+--------------------+--------------------+--------------------+-------------------+--------------------+----+
# |         1|        A Bike Store|adventure-works\p...|orlando0@adventur...|       245-555-0173|  Mr. Orlando N. Gee|null|
# |         2|  Progressive Sports|adventure-works\d...|keith0@adventure-...|       170-555-0127|   Mr. Keith  Harris|null|
# |         3|Advanced Bike Com...|adventure-works\j...|donna0@adventure-...|       279-555-0130|Ms. Donna F. Carr...|null|
# |         4|Modular Cycle Sys...|adventure-works\j...|janet1@adventure-...|       710-555-0173|  Ms. Janet M. Gates|null|
# |         5|Metropolitan Spor...|adventure-works\shu0|lucy0@adventure-w...|       828-555-0186|Mr. Lucy  Harrington|null|
# |         6|Aerobic Exercise ...|adventure-works\l...|rosmarie0@adventu...|       244-555-0112|Ms. Rosmarie J. C...|null|
# |         7|    Associated Bikes|adventure-works\shu0|dominic0@adventur...|       192-555-0173| Mr. Dominic P. Gash|null|
# |        10|Rural Cycle Emporium|adventure-works\j...|kathleen0@adventu...|       150-555-0127|Ms. Kathleen M. G...|null|
# |        11|         Sharp Bikes|adventure-works\j...|katherine0@advent...|       926-555-0159|Ms. Katherine  Ha...|null|
# |        12|Bikes and Motorbikes|adventure-works\g...|johnny0@adventure...|       112-555-0191|Mr. Johnny A. Caprio|null|
# |        16| Bulk Discount Store|adventure-works\jae0|christopher1@adve...|1 (11) 500 555-0132|Mr. Christopher R...|null|
# |        18|       Catalog Store|adventure-works\m...|david20@adventure...|       440-555-0132|    Mr. David J. Liu|null|
# |        19|   Center Cycle Shop|adventure-works\p...|john8@adventure-w...|       521-555-0195|  Mr. John A. Beaver|null|
# |        20|Central Discount ...|adventure-works\d...|jean1@adventure-w...|       582-555-0113| Ms. Jean P. Handley|null|
# |        21|Chic Department S...|adventure-works\j...|jinghao1@adventur...|       928-555-0116|        Jinghao  Liu|null|
# |        22|      Travel Systems|adventure-works\j...|linda4@adventure-...|       121-555-0121|Ms. Linda E. Burnett|null|
# |        23|          Bike World|adventure-works\shu0|kerim0@adventure-...|       216-555-0122|    Mr. Kerim  Hanif|null|
# |        24|Eastside Departme...|adventure-works\l...|kevin5@adventure-...|       926-555-0164|      Mr. Kevin  Liu|null|
# |        25|Coalition Bike Co...|adventure-works\shu0|donald0@adventure...|       357-555-0161|Mr. Donald L. Bla...|null|
# |        28|Commuter Bicycle ...|adventure-works\j...|jackie0@adventure...|       972-555-0163|Ms. Jackie E. Bla...|null|
# +----------+--------------------+--------------------+--------------------+-------------------+--------------------+----+
# only showing top 20 rows

# %%
customer_data_processed= df_modified.write.mode( "overwrite").parquet('/FileStore/initial data/customer_data_processed.csv')

# %%
df_modified.write.mode("overwrite").format("parquet").saveAsTable('firstexp.customerdata')
